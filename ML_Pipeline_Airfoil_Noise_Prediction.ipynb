# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMSkillsNetworkBD0231ENCoursera2789-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# ## Final Project - Build an ML Pipeline for Airfoil noise prediction

# %% [markdown]
# Estimated time needed: **90** minutes

# %% [markdown]
# ## Scenario

# %% [markdown]
# You are a data engineer at an aeronautics consulting company. Your company prides itself in being able to efficiently design airfoils for use in planes and sports cars. Data scientists in your office need to work with different algorithms and data in different formats. While they are good at Machine Learning, they count on you to be able to do ETL jobs and build ML pipelines. In this project you will use the modified version of the NASA Airfoil Self Noise dataset. You will clean this dataset, by dropping the duplicate rows, and removing the rows with null values. You will create an ML pipe line to create a model that will predict the SoundLevel based on all the other columns. You will evaluate the model and towards the end you will persist the model.

# %% [markdown]
# ## Objectives
#
# In this 4 part assignment you will:
#
# - Part 1 Perform ETL activity
#   - Load a csv dataset
#   - Remove duplicates if any
#   - Drop rows with null values if any
#   - Make transformations
#   - Store the cleaned data in parquet format
# - Part 2 Create a  Machine Learning Pipeline
#   - Create a machine learning pipeline for prediction
# - Part 3 Evaluate the Model
#   - Evaluate the model using relevant metrics
# - Part 4 Persist the Model
#   - Save the model for future production use
#   - Load and verify the stored model

# %% [markdown]
# ## Datasets
#
# In this lab you will be using dataset(s):
#
#  - The original dataset can be found here NASA airfoil self noise dataset. https://archive.ics.uci.edu/dataset/291/airfoil+self+noise
#
#  - This dataset is licensed under a Creative Commons Attribution 4.0 International (CC BY 4.0) license.

# %% [markdown]
# Diagram of an airfoil. - For informational purpose

# %% [markdown]
# ![Airfoil with flow](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/images/Airfoil_with_flow.png)

# %% [markdown]
# Diagram showing the Angle of attack. - For informational purpose

# %% [markdown]
# ![Airfoil angle of attack](https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/images/Airfoil_angle_of_attack.jpg)

# %% [markdown]
# ## Before you Start

# %% [markdown]
# Before you start attempting this project it is highly recommended that you finish the practice project.

# %% [markdown]
# ## Setup

# %% [markdown]
# For this lab, we will be using the following libraries:
#
# *   [`PySpark`](https://spark.apache.org/docs/latest/api/python/index.html?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMSkillsNetworkBD0231ENCoursera2789-2023-01-01) for connecting to the Spark Cluster

# %% [markdown]
# ### Installing Required Libraries
#
# Spark Cluster is pre-installed in the Skills Network Labs environment. However, you need libraries like pyspark and findspark to
#  connect to this cluster.

# %% [markdown]
# The following required libraries are __not__ pre-installed in the Skills Network Labs environment. __You will need to run the following cell__ to install them:

# %%
# !pip install pyspark==3.1.2 -q
# !pip install findspark -q
# Out:
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %% [markdown]
# ### Importing Required Libraries
#
# _We recommend you import all required libraries in one place (here):_

# %%
# You can also use this section to suppress warnings generated by your code:
def warn(*args, **kwargs):
    pass
import warnings
warnings.warn = warn
warnings.filterwarnings('ignore')

# FindSpark simplifies the process of using Apache Spark with Python

import findspark
findspark.init()

# %% [markdown]
# ## Part 1 - Perform ETL activity

# %% [markdown]
# ### Task 1 - Import required libraries

# %%
from pyspark.sql import SparkSession
from pyspark.ml import Pipeline
from pyspark.ml.pipeline import PipelineModel
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.regression import LinearRegression
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import StandardScaler
# import functions/Classes for metrics
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

# %% [markdown]
# ### Task 2 - Create a spark session

# %%
#Create a SparkSession
spark = SparkSession.builder.appName("Final").getOrCreate()

# %% [markdown]
# ### Task 3 - Load the csv file into a dataframe

# %% [markdown]
# Download the data file.
#
# NOTE : Please ensure you use the dataset below and not the original dataset mentioned above.

# %%
# !wget https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/datasets/NASA_airfoil_noise_raw.csv
# Out:
# --2024-02-21 15:42:42--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMSkillsNetwork-BD0231EN-Coursera/datasets/NASA_airfoil_noise_raw.csv
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response...
# 200 OK
# Length: 60682 (59K) [text/csv]
# Saving to: 'NASA_airfoil_noise_raw.csv.7'
#
# NASA_airfoil_noise_ 100%[===================>]  59.26K  --.-KB/s    in 0.03s
#
# 2024-02-21 15:42:42 (1.76 MB/s) - 'NASA_airfoil_noise_raw.csv.7' saved [60682/60682]

# %% [markdown]
# Load the dataset into the spark dataframe

# %%
df = spark.read.csv("NASA_airfoil_noise_raw.csv", header=True, inferSchema=True)

# %% [markdown]
# ### Task 4 - Print top 5 rows of the dataset

# %%
df.show()
# Out:
# +---------+-------------+-----------+------------------+-----------------------+----------+
# |Frequency|AngleOfAttack|ChordLength|FreeStreamVelocity|SuctionSideDisplacement|SoundLevel|
# +---------+-------------+-----------+------------------+-----------------------+----------+
# |      800|          0.0|     0.3048|              71.3|             0.00266337|   126.201|
# |     1000|          0.0|     0.3048|              71.3|             0.00266337|   125.201|
# |     1250|          0.0|     0.3048|              71.3|             0.00266337|   125.951|
# |     1600|          0.0|     0.3048|              71.3|             0.00266337|   127.591|
# |     2000|          0.0|     0.3048|              71.3|             0.00266337|   127.461|
# |     2500|          0.0|     0.3048|              71.3|             0.00266337|   125.571|
# |     3150|          0.0|     0.3048|              71.3|             0.00266337|   125.201|
# |     4000|          0.0|     0.3048|              71.3|             0.00266337|   123.061|
# |     5000|          0.0|     0.3048|              71.3|             0.00266337|   121.301|
# |     6300|          0.0|     0.3048|              71.3|             0.00266337|   119.541|
# |     8000|          0.0|     0.3048|              71.3|             0.00266337|   117.151|
# |    10000|          0.0|     0.3048|              71.3|             0.00266337|   115.391|
# |    12500|          0.0|     0.3048|              71.3|             0.00266337|   112.241|
# |    16000|          0.0|     0.3048|              71.3|             0.00266337|   108.721|
# |      500|          0.0|     0.3048|              55.5|             0.00283081|   126.416|
# |      630|          0.0|     0.3048|              55.5|             0.00283081|   127.696|
# |      800|          0.0|     0.3048|              55.5|             0.00283081|   128.086|
# |     1000|          0.0|     0.3048|              55.5|             0.00283081|   126.966|
# |     1250|          0.0|     0.3048|              55.5|             0.00283081|   126.086|
# |     1600|          0.0|     0.3048|              55.5|             0.00283081|   126.986|
# +---------+-------------+-----------+------------------+-----------------------+----------+
# only showing top 20 rows

# %% [markdown]
# ### Task 6 - Print the total number of rows in the dataset

# %%
#your code goes here
rowcount1 = df.count()
print(rowcount1)
# Out:
# 1522

# %% [markdown]
# ### Task 7 - Drop all the duplicate rows from the dataset

# %%
df = df.dropDuplicates()

# %% [markdown]
# ### Task 8 - Print the total number of rows in the dataset

# %%
#your code goes here

rowcount2 = df.count()
print(rowcount2)
# Out:
# 1503

# %% [markdown]
# ### Task 9 - Drop all the rows that contain null values from the dataset

# %%
df = df.dropna()

# %% [markdown]
# ### Task 10 - Print the total number of rows in the dataset

# %%
rowcount3 = df.count()
print(rowcount3)
# Out:
# 1499

# %% [markdown]
# ### Task 11 - Rename the column "SoundLevel" to "SoundLevelDecibels"Drop

# %%
# your code goes here

df = df.withColumnRenamed("SoundLevel", "SoundLevelDecibels")

# %% [markdown]
# ### Task 12 - Save the dataframe in parquet formant, name the file as "NASA_airfoil_noise_cleaned.parquet"

# %%
df.write.mode("overwrite").parquet("NASA_airfoil_noise_cleaned.parquet")

# %% [markdown]
# #### Part 1 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# Use the answers here to answer the final evaluation quiz in the next section.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 1 - Evaluation")

print("Total rows = ", rowcount1)
print("Total rows after dropping duplicate rows = ", rowcount2)
print("Total rows after dropping duplicate rows and rows with null values = ", rowcount3)
print("New column name = ", df.columns[-1])

import os

print("NASA_airfoil_noise_cleaned.parquet exists :", os.path.isdir("NASA_airfoil_noise_cleaned.parquet"))
# Out:
# Part 1 - Evaluation
# Total rows =  1522
# Total rows after dropping duplicate rows =  1503
# Total rows after dropping duplicate rows and rows with null values =  1499
# New column name =  SoundLevelDecibels
# NASA_airfoil_noise_cleaned.parquet exists : True

# %% [markdown]
# ## Part - 2 Create a  Machine Learning Pipeline

# %% [markdown]
# ### Task 1 - Load data from "NASA_airfoil_noise_cleaned.parquet" into a dataframe

# %%
#your code goes here

df = spark.read.parquet("NASA_airfoil_noise_cleaned.parquet/")

# %% [markdown]
# ### Task 2 - Print the total number of rows in the dataset

# %%
#your code goes here

NASA_parquet_rowcount = df.count()
print(NASA_parquet_rowcount)
# Out:
# 1499

# %% [markdown]
# ### Task 3 - Define the VectorAssembler pipeline stage

# %% [markdown]
# Stage 1 - Assemble the input columns into a single column "features". Use all the columns except SoundLevelDecibels as input features.

# %%
#your code goes here
assembler = VectorAssembler(inputCols=["Frequency","AngleOfAttack","ChordLength","FreeStreamVelocity","SuctionSideDisplacement"], outputCol="features")

# %% [markdown]
# ### Task 4 - Define the StandardScaler pipeline stage

# %% [markdown]
# Stage 2 - Scale the "features" using standard scaler and store in "scaledFeatures" column

# %%
scaler = StandardScaler(inputCol="features", outputCol="scaledFeatures", withStd=True, withMean=True)

# %% [markdown]
# ### Task 5 - Define LinearRegression pipeline stage

# %% [markdown]
# Stage 3 - Create a LinearRegression stage to predict "SoundLevelDecibels"
#
# **Note:You need to use the scaledfeatures retreived in the previous step.**

# %%
lr = LinearRegression(featuresCol="scaledFeatures", labelCol="SoundLevelDecibels")

# %% [markdown]
# ### Task 6 - Build the pipeline

# %% [markdown]
# Build a pipeline using the above three stages

# %%
pipeline = Pipeline(stages=[assembler, scaler, lr])

# %% [markdown]
# ### Task 7 - Split the data

# %%
# Split the data into training and testing sets with 70:30 split.
# set the value of seed to 42
# the above step is very important. DO NOT set the value of seed to any other value other than 42.

(trainingData, testingData) = df.randomSplit([0.7,0.3], seed=42)

# %% [markdown]
# ### Task 8 - Fit the pipeline

# %%
# Fit the pipeline using the training data
# your code goes here

PipelineModel = pipeline.fit(trainingData)
# Out:
# 24/02/21 15:42:50 WARN Instrumentation: [43827eb4] regParam is zero, which might cause numerical instability and overfitting.

# %% [markdown]
# #### Part 2 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# Use the answers here to answer the final evaluation quiz in the next section.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 2 - Evaluation")
print("Total rows = ", NASA_parquet_rowcount)
ps = [str(x).split("_")[0] for x in pipeline.getStages()]

print("Pipeline Stage 1 = ", ps[0])
print("Pipeline Stage 2 = ", ps[1])
print("Pipeline Stage 3 = ", ps[2])

print("Label column = ", lr.getLabelCol())
# Out:
# Part 2 - Evaluation
# Total rows =  1499
# Pipeline Stage 1 =  VectorAssembler
# Pipeline Stage 2 =  StandardScaler
# Pipeline Stage 3 =  LinearRegression
# Label column =  SoundLevelDecibels

# %% [markdown]
# ## Part 3 - Evaluate the Model

# %% [markdown]
# ### Task 1 - Predict using the model

# %%
# Make predictions on testing data
# your code goes here

predictions = PipelineModel.transform(testingData)

# %% [markdown]
# ### Task 2 - Print the MSE

# %%
evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="SoundLevelDecibels", metricName="mse")
mse = evaluator.evaluate(predictions)
print(mse)
# Out:
# 25.585013938325414

# %% [markdown]
# ### Task 3 - Print the MAE

# %%
evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="SoundLevelDecibels", metricName="mae")
mae = evaluator.evaluate(predictions)
print(mae)
# Out:
# 3.8803113870741575

# %% [markdown]
# ### Task 4 - Print the R-Squared(R2)

# %%
evaluator = RegressionEvaluator(predictionCol="prediction", labelCol="SoundLevelDecibels", metricName="r2")
r2 = evaluator.evaluate(predictions)
print(r2)
# Out:
# 0.5024167247636051

# %%
PipelineModel.stages
# Out:
# [VectorAssembler_265fbcbcb98a,
#  StandardScalerModel: uid=StandardScaler_89ec806163c6, numFeatures=5, withMean=true, withStd=true,
#  LinearRegressionModel: uid=LinearRegression_7605585642d3, numFeatures=5]

# %% [markdown]
# #### Part 3 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# Use the answers here to answer the final evaluation quiz in the next section.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 3 - Evaluation")

print("Mean Squared Error = ", round(mse,2))
print("Mean Absolute Error = ", round(mae,2))
print("R Squared = ", round(r2,2))

lrModel = PipelineModel.stages[-1]

print("Intercept = ", round(lrModel.intercept,2))
# Out:
# Part 3 - Evaluation
# Mean Squared Error =  25.59
# Mean Absolute Error =  3.88
# R Squared =  0.5
# Intercept =  124.71

# %% [markdown]
# ## Part 4 - Persist the Model

# %% [markdown]
# ### Task 1 - Save the model to the path "Final_Project"

# %%
# Save the pipeline model as "Final_Project"
PipelineModel.write().overwrite().save("Final_Project")

# %% [markdown]
# ### Task 2 - Load the model from the path "Final_Project"

# %%
# Load the pipeline model you have created in the previous step
loadedPipelineModel = PipelineModel.load("Final_Project")

# %% [markdown]
# ### Task 3 - Make predictions using the loaded model on the testdata

# %%
# Use the loaded pipeline model and make predictions using testingData
predictions = loadedPipelineModel.transform(testingData)

# %% [markdown]
# ### Task 4 - Show the predictions

# %%
predictions.show()
# Out:
# +---------+-------------+-----------+------------------+-----------------------+------------------+--------------------+--------------------+------------------+
# |Frequency|AngleOfAttack|ChordLength|FreeStreamVelocity|SuctionSideDisplacement|SoundLevelDecibels|            features|      scaledFeatures|        prediction|
# +---------+-------------+-----------+------------------+-----------------------+------------------+--------------------+--------------------+------------------+
# |      200|         12.3|     0.1016|              39.6|              0.0408268|           128.545|[200.0,12.3,0.101...|[-0.8657214244460...|121.55186309681399|
# |      200|         15.6|     0.1016|              71.3|              0.0437259|           130.898|[200.0,15.6,0.101...|[-0.8657214244460...|122.97369641064255|
# |      200|         17.4|     0.0254|              55.5|              0.0165706|           109.951|[200.0,17.4,0.025...|[-0.8657214244460...|127.66190307397632|
# |      200|         17.4|     0.0254|              71.3|               0.016104|           112.506|[200.0,17.4,0.025...|[-0.8657214244460...|129.29487735788595|
# |      250|          7.3|     0.2286|              31.7|              0.0132672|           130.089|[250.0,7.3,0.2286...|[-0.8498539913341...|122.14646195851671|
# |      250|          7.3|     0.2286|              71.3|              0.0104404|           139.918|[250.0,7.3,0.2286...|[-0.8498539913341...|126.49149018510477|
# |      250|          8.9|     0.1016|              71.3|              0.0103088|           134.533|[250.0,8.9,0.1016...|[-0.8498539913341...| 130.5789019416383|
# |      315|          3.0|     0.3048|              39.6|             0.00495741|           123.312|[315.0,3.0,0.3048...|[-0.8292263282886...|122.95864660660564|
# |      315|          5.4|     0.1524|              31.7|             0.00525474|           125.741|[315.0,5.4,0.1524...|[-0.8292263282886...|126.82844188868921|
# |      315|          7.3|     0.2286|              71.3|              0.0104404|           139.808|[315.0,7.3,0.2286...|[-0.8292263282886...|126.41222419318422|
# |      315|          9.9|     0.1524|              39.6|              0.0233328|           128.595|[315.0,9.9,0.1524...|[-0.8292263282886...|123.12506179941967|
# |      315|         12.6|     0.1524|              71.3|              0.0483159|           128.484|[315.0,12.6,0.152...|[-0.8292263282886...|121.41662684962749|
# |      315|         12.7|     0.0254|              39.6|              0.0130253|           123.537|[315.0,12.7,0.025...|[-0.8292263282886...|128.29922688544528|
# |      315|         12.7|     0.0254|              71.3|              0.0121808|           122.938|[315.0,12.7,0.025...|[-0.8292263282886...|131.56156062152215|
# |      315|         15.4|     0.0508|              39.6|              0.0282593|           124.493|[315.0,15.4,0.050...|[-0.8292263282886...|124.00416586300716|
# |      315|         15.6|     0.1016|              39.6|              0.0528487|           122.754|[315.0,15.6,0.101...|[-0.8292263282886...|118.31112038784384|
# |      315|         17.4|     0.0254|              71.3|               0.016104|           115.846|[315.0,17.4,0.025...|[-0.8292263282886...| 129.1546375260265|
# |      400|          5.3|     0.2286|              39.6|             0.00614329|           131.221|[400.0,5.3,0.2286...|[-0.8022516919984...| 124.5989397168422|
# |      400|          7.3|     0.2286|              55.5|              0.0111706|           135.924|[400.0,7.3,0.2286...|[-0.8022516919984...|124.63547302227073|
# |      400|          8.4|     0.0508|              31.7|             0.00580776|           120.076|[400.0,8.4,0.0508...|[-0.8022516919984...| 129.2322125512867|
# +---------+-------------+-----------+------------------+-----------------------+------------------+--------------------+--------------------+------------------+
# only showing top 20 rows

# %% [markdown]
# #### Part 4 - Evaluation

# %% [markdown]
# Run the code cell below.<br>
# Use the answers here to answer the final evaluation quiz in the next section.<br>
# If the code throws up any errors, go back and review the code you have written.

# %%
print("Part 4 - Evaluation")

loadedmodel = loadedPipelineModel.stages[-1]
totalstages = len(loadedPipelineModel.stages)
inputcolumns = loadedPipelineModel.stages[0].getInputCols()

print("Number of stages in the pipeline = ", totalstages)
for i,j in zip(inputcolumns, loadedmodel.coefficients):
    print(f"Coefficient for {i} is {round(j,4)}")
# Out:
# Part 4 - Evaluation
# Number of stages in the pipeline =  3
# Coefficient for Frequency is -3.8427
# Coefficient for AngleOfAttack is -2.3102
# Coefficient for ChordLength is -3.4459
# Coefficient for FreeStreamVelocity is 1.5463
# Coefficient for SuctionSideDisplacement is -2.0173

# %% [markdown]
# ### Stop Spark Session

# %%
spark.stop()

# %% [markdown]
# ## Authors

# %% [markdown]
# [Ramesh Sannareddy](https://www.linkedin.com/in/rsannareddy/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMBD0231ENSkillsNetwork866-2023-01-01)

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# ## Change Log

# %% [markdown]
# |Date (YYYY-MM-DD)|Version|Changed By|Change Description|
# |-|-|-|-|
# |2023-05-26|0.1|Ramesh Sannareddy|Initial Version Created|

# %% [markdown]
# Copyright © 2023 IBM Corporation. All rights reserved.
